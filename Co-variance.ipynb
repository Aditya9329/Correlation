# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import statsmodels.api as sm

# %%
df_slry  = pd.read_csv('Employee_Salary_Dataset.csv')

# %%
df_slry.head(5)
# Out:
#    ID  Experience_Years  Age  Gender  Salary
# 0   1                 5   28  Female  250000
# 1   2                 1   21    Male   50000
# 2   3                 3   23  Female  170000
# 3   4                 2   22    Male   25000
# 4   5                 1   17    Male   10000

# %%
x = df_slry.drop(columns=['ID','Gender','Salary'])

# %%
y = df_slry['Salary']

# %%
x.head(2)
# Out:
#    Experience_Years  Age
# 0                 5   28
# 1                 1   21

# %%
y.head(2)
# Out:
# 0    250000
# 1     50000
# Name: Salary, dtype: int64

# %%
X = sm.add_constant(x)

# %%
X
# Out:
#     const  Experience_Years  Age
# 0     1.0                 5   28
# 1     1.0                 1   21
# 2     1.0                 3   23
# 3     1.0                 2   22
# 4     1.0                 1   17
# 5     1.0                25   62
# 6     1.0                19   54
# 7     1.0                 2   21
# 8     1.0                10   36
# 9     1.0                15   54
# 10    1.0                 4   26
# 11    1.0                 6   29
# 12    1.0                14   39
# 13    1.0                11   40
# 14    1.0                 2   23
# 15    1.0                 4   27
# 16    1.0                10   34
# 17    1.0                15   54
# 18    1.0                 2   21
# 19    1.0                10   36
# 20    1.0                15   54
# 21    1.0                 4   26
# 22    1.0                 5   29
# 23    1.0                 1   21
# 24    1.0                 4   23
# 25    1.0                 3   22
# 26    1.0                 1   18
# ...

# %%
model=sm.OLS(y,x).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared (uncentered):                   0.630
# Model:                            OLS   Adj. R-squared (uncentered):              0.607
# Method:                 Least Squares   F-statistic:                              28.05
# Date:                Tue, 09 Aug 2022   Prob (F-statistic):                    7.64e-08
# Time:                        00:47:00   Log-Likelihood:                         -562.01
# No. Observations:                  35   AIC:                                      1128.
# Df Residuals:                      33   BIC:                                      1131.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
X.iloc[:,1:].corr()
# Out:
#                   Experience_Years       Age
# Experience_Years          1.000000  0.973708
# Age                       0.973708  1.000000

# %%
#### Here Multi-collinearity occured here ,
# so i will drop one of my feature and top of one feature only i wil build my model
